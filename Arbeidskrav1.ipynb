# %%
km = 10000 # [kilometer i året]
elb_fors = 5000 # [forsikring elbil]
bb_fors = 7500 # [forsikring bensinbil]
traf_fors = 8.38 * 365 # [traffikkforsikringsavgift]
elb_drivstoff = ((km * 0.2) * 2) # [drivstoffbruk elbil]
bb_drivstoff = (km * 1) # [drivstoffbruk bensinbil]
elb_avg = (km * 0.1) # [bomavgift elbil]
bb_avg = (km * 0.3) # [bomavgift bensinbil]

tot_elb_arlig = elb_fors + traf_fors + elb_drivstoff + elb_avg # [årlig totalkostnad elbil]
tot_bb_arlig = bb_fors + traf_fors + bb_drivstoff + bb_avg # [årlig totalkostnad bensinbil]
diff = tot_bb_arlig - tot_elb_arlig # [kostnadsdifferanse]

print ( 'Årlige totalkostnader for bruk av elbil er: ', tot_elb_arlig)
print ( 'Årlige totalkostnader for bruk av bensinbil er: ', tot_bb_arlig)
print ( 'Årlig kostnadsdifferanse basert på informasjonen er: ', diff)
# Out:
# Årlige totalkostnader for bruk av elbil er:  13058.7
# Årlige totalkostnader for bruk av bensinbil er:  23558.7
# Årlig kostnadsdifferanse basert på informasjonen er:  10500.0
